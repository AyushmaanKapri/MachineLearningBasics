# %%
# with open('example.txt','r+') as file:
#     content = file.read()
#     file.write('\nAppended Line')
#     print(content)
with open('binary.bin', 'wb') as file:
    binary_data = b'\x49\x20\x6c\x6f\x76\x65\x20\x79\x6f\x75\x20\x4d\x75\x73\x6b\x61\x6e'
    file.write(binary_data)
    print("Binary data written to file.")
with open('example.txt','r') as file:
    for line in file:
        print(line.strip())
# Out:
# Binary data written to file.
#
# Appended Line
# Appended Line
# My Name is AYush
# Appended Line
# Appended Line
